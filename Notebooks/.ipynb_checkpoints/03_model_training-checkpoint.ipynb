# %%
pip install -r requirements.txt
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv("../Data/processed_data.csv")

# %%
df["penicillin"] = df.groupby("batch_id")["penicillin"].ffill()
df["biomass"] = df.groupby("batch_id")["biomass"].ffill()
df["penicillin_lag1"] = df["penicillin_lag1"].fillna(df["penicillin"])
df["penicillin_next"] = df.groupby("batch_id")["penicillin"].shift(-1)
df["biomass_next"] = df.groupby("batch_id")["biomass"].shift(-1)

# Create delta targets
df["penicillin_delta"] = df["penicillin_next"] - df["penicillin"]
df["biomass_delta"] = df["biomass_next"] - df["biomass"]

df = df[
    df["penicillin_next"].notna() &
    df["biomass_next"].notna() &
    df["penicillin_delta"].notna() &
    df["biomass_delta"].notna()
].copy()

# %%
df.columns
# Out:
# Index(['time', 'aeration', 'rpm', 'feed_rate', 'Acid flow', 'Base flow',
#        'Heating/cooling water flow rate(Fc:L/h)',
#        'Heating water flow rate(Fh:L/h)',
#        'Water for injection/dilution(Fw:L/h)',
#        'Air head pressure(pressure:bar)', 'Dumped broth flow(Fremoved:L/h)',
#        'Substrate concentration(S:g/L)', 'do', 'penicillin', 'Vessel volume',
#        'Vessel Weight(Wt:Kg)', 'ph', 'temp', 'Generated heat(Q:kJ)',
#        'carbon dioxide percent in off-gas(CO2outgas:%)',
#        'PAA flow(Fpaa:PAA flow (L/h))',
#        'PAA concentration offline(PAA_offline:PAA (g L^{-1}))',
#        'Oil flow(Foil:L/hr)',
#        'NH_3 concentration off-line(NH3_offline:NH3 (g L^{-1}))', 'our',
#        'Oxygen in percent in off-gas(O2:O2  (%))',
#        'Offline Penicillin concentration(P_offline:P(g L^{-1}))', 'biomass',
#        'cer', 'Ammonia shots(NH3_shots:kgs)',
#        'Viscosity(Viscosity_offline:centPoise)',
# ...

# %%
pip install scikit-learn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
features = [
    "time",
    "rpm",
    "aeration",
    "feed_rate",
    "cum_feed",
    "our",
    "cer",
    "do",
    "temp",
    "ph",
    "mixing_intensity",
    "oxygen_efficiency",
    "growth_rate",
    "biomass_lag1",
    "penicillin_lag1",
    "our_lag1",
    "Base flow", 
    "Acid flow", 
    "Vessel volume"
]

# %%
batches = df["batch_id"].unique()

train_batches = batches[:int(0.8 * len(batches))]
test_batches = batches[int(0.8 * len(batches)):]

train = df[df["batch_id"].isin(train_batches)]
test = df[df["batch_id"].isin(test_batches)]

# %%
X_train = train[features]
X_test = test[features]

y_train_p = train["penicillin_delta"]
y_test_p = test["penicillin_delta"]

y_train_x = train["biomass_delta"]
y_test_x = test["biomass_delta"]

# %%
from sklearn.ensemble import RandomForestRegressor

model_p = RandomForestRegressor(
    n_estimators=300,
    max_depth=12,
    min_samples_leaf=3,
    max_features=0.6,
    n_jobs=-1,
    random_state=42
)
model_x = RandomForestRegressor(
    n_estimators=300,
    max_depth=12,
    min_samples_leaf=3,
    max_features=0.6,
    n_jobs=-1,
    random_state=42
)

model_p.fit(X_train, y_train_p)
model_x.fit(X_train, y_train_x)
# Out:
# RandomForestRegressor(max_depth=12, max_features=0.6, min_samples_leaf=3,
#                       n_estimators=300, n_jobs=-1, random_state=42)

# %%
delta_pred_p = model_p.predict(X_test)
delta_pred_x = model_x.predict(X_test)
from sklearn.metrics import mean_squared_error
import numpy as np

rmse_p = np.sqrt(mean_squared_error(test["penicillin_delta"], delta_pred_p))
rmse_x = np.sqrt(mean_squared_error(test["biomass_delta"], delta_pred_x))
print (rmse_p)
print (rmse_x)
import matplotlib.pyplot as plt

plt.figure(figsize=(10,5))
plt.plot(test["penicillin_delta"].values, label="Actual")
plt.plot(delta_pred_p, label="Predicted")
plt.title("Penicillin Prediction (Delta Model)")
plt.legend()
plt.show()

plt.figure(figsize=(10,5))
plt.plot(test["biomass_delta"].values, label="Actual")
plt.plot(delta_pred_x, label="Predicted")
plt.title("Biomass Prediction (Delta Model)")
plt.legend()
plt.show()
# Out:
# 0.006473318790168954
# 0.0023453121542189492

# %%
penicillin_pred = test["penicillin"] + delta_pred_p

rmse_p = np.sqrt(mean_squared_error(test["penicillin_next"], penicillin_pred))
print("Penicillin RMSE:", rmse_p)

biomass_pred = test["biomass"] + delta_pred_x

rmse_x = np.sqrt(mean_squared_error(test["biomass_next"], biomass_pred))
print("Biomass RMSE:", rmse_x)
# Out:
# Penicillin RMSE: 0.006473318790168958
# Biomass RMSE: 0.0023453121542189597

# %%
delta_pred_p = model_p.predict(X_test)
delta_pred_x = model_x.predict(X_test)
importance = pd.Series(model_p.feature_importances_, index=features)
importance = importance.sort_values()

plt.figure(figsize=(8,6))
importance.plot(kind="barh")
plt.title("Feature Importance - Penicillin")
plt.show()

importance1 = pd.Series(model_x.feature_importances_, index=features)
importance1 = importance1.sort_values()
plt.figure(figsize=(8,6))
importance1.plot(kind="barh")
plt.title("Feature Importance - Biomass")
plt.show()

# %%
#ADDITIONAL CROSS-VALIDATION TEST (optional)
from sklearn.metrics import mean_squared_error
import numpy as np
import pandas as pd
import joblib
from sklearn.ensemble import RandomForestRegressor

def lobo_cross_validation(df, features):
    """
    Leave-One-Batch-Out Cross Validation.
    For each batch: train on all OTHER batches, test on this one.
    Gives a honest estimate of how well the model generalises
    to a completely unseen batch — which is exactly your use case.
    """
    batches  = df["batch_id"].unique()
    results  = []

    for held_out in batches:
        train = df[df["batch_id"] != held_out]
        test  = df[df["batch_id"] == held_out]

        X_train = train[features]
        X_test  = test[features]

        model_p = RandomForestRegressor(
            n_estimators=300, max_depth=12,
            min_samples_leaf=3, max_features=0.6,
            n_jobs=-1, random_state=42
        )
        model_p.fit(X_train, train["penicillin_delta"])

        model_x = RandomForestRegressor(
            n_estimators=300, max_depth=12,
            min_samples_leaf=3, max_features=0.6,
            n_jobs=-1, random_state=42
        )
        model_x.fit(X_train, train["biomass_delta"])

        p_pred = test["penicillin"] + model_p.predict(X_test)
        x_pred = test["biomass"]    + model_x.predict(X_test)

        rmse_p = np.sqrt(mean_squared_error(test["penicillin_next"], p_pred))
        rmse_x = np.sqrt(mean_squared_error(test["biomass_next"],    x_pred))

        results.append({
            "held_out_batch": held_out,
            "penicillin_rmse": rmse_p,
            "biomass_rmse":    rmse_x,
        })

        print(f"Batch {held_out} held out | "
              f"Pen RMSE: {rmse_p:.4f} | Bio RMSE: {rmse_x:.4f}")

    results_df = pd.DataFrame(results)

    print("\n=== LOBO-CV Summary ===")
    print(f"Penicillin RMSE — mean: {results_df['penicillin_rmse'].mean():.4f} "
          f"± {results_df['penicillin_rmse'].std():.4f}")
    print(f"Biomass RMSE    — mean: {results_df['biomass_rmse'].mean():.4f} "
          f"± {results_df['biomass_rmse'].std():.4f}")

    return results_df

df = pd.read_csv("../Data/processed_data.csv")
df["penicillin"]      = df.groupby("batch_id")["penicillin"].ffill()
df["biomass"]         = df.groupby("batch_id")["biomass"].ffill()
df["penicillin_lag1"] = df["penicillin_lag1"].fillna(df["penicillin"])

df["penicillin_next"]  = df.groupby("batch_id")["penicillin"].shift(-1)
df["biomass_next"]     = df.groupby("batch_id")["biomass"].shift(-1)
df["penicillin_delta"] = df["penicillin_next"] - df["penicillin"]
df["biomass_delta"]    = df["biomass_next"]    - df["biomass"]

df = df[
    df["penicillin_next"].notna() &
    df["biomass_next"].notna() &
    df["penicillin_delta"].notna() &
    df["biomass_delta"].notna()
].copy()

FEATURES = [
    "time",
    "rpm",
    "aeration",
    "feed_rate",
    "cum_feed",
    "our",
    "cer",
    "do",
    "temp",
    "ph",
    "mixing_intensity",
    "oxygen_efficiency",
    "growth_rate",
    "biomass_lag1",
    "penicillin_lag1",
    "our_lag1",
    "Base flow", 
    "Acid flow", 
    "Vessel volume"
]

results_df = lobo_cross_validation(df, FEATURES)
# Out:
# Batch 1 held out | Pen RMSE: 0.0054 | Bio RMSE: 0.0026
# Batch 2 held out | Pen RMSE: 0.0082 | Bio RMSE: 0.0015
# Batch 3 held out | Pen RMSE: 0.0112 | Bio RMSE: 0.0013
# Batch 4 held out | Pen RMSE: 0.0049 | Bio RMSE: 0.0015
# Batch 5 held out | Pen RMSE: 0.0054 | Bio RMSE: 0.0020
# Batch 6 held out | Pen RMSE: 0.0134 | Bio RMSE: 0.0036
# Batch 7 held out | Pen RMSE: 0.0075 | Bio RMSE: 0.0014
# Batch 8 held out | Pen RMSE: 0.0061 | Bio RMSE: 0.0022
# Batch 9 held out | Pen RMSE: 0.0070 | Bio RMSE: 0.0024
# Batch 10 held out | Pen RMSE: 0.0059 | Bio RMSE: 0.0014
#
# === LOBO-CV Summary ===
# Penicillin RMSE — mean: 0.0075 ± 0.0028
# Biomass RMSE    — mean: 0.0020 ± 0.0007
